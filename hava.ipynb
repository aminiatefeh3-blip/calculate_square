# %%
import requests,json
try:
    ++
    
  result = requests.get('https://stgdhtjkgoogle.com')
  print(result.status_code)
except:
  print("error")
# Out:
# error

# %%
api_key="9adced7ddff5c6dc7f031455d3dec00e"
base_url = "http://api.openweathermap.org/data/2.5/weather?"
city_name = input("enter city name:")
complete_url= base_url+"appid=" + api_key + "&q="+ city_name

# %%
import requests

api_key = "9adced7ddff5c6dc7f031455d3dec00e"
base_url = "http://api.openweathermap.org/data/2.5/weather?"
city_name = "Tehran"  # به جای input، فعلاً ثابت بگذارید تا مطمئن شویم

complete_url = base_url + "appid=" + api_key + "&q=" + city_name
response = requests.get(complete_url)
data = response.json()

# این خط را حتماً اضافه کنید تا ببینیم چه جوابی می‌آید
print(data)
# Out:
# {'coord': {'lon': 51.4215, 'lat': 35.6944}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 300.77, 'feels_like': 299.57, 'temp_min': 300.77, 'temp_max': 300.77, 'pressure': 1006, 'humidity': 17, 'sea_level': 1006, 'grnd_level': 859}, 'visibility': 10000, 'wind': {'speed': 2.68, 'deg': 130}, 'clouds': {'all': 0}, 'dt': 1781412405, 'sys': {'type': 2, 'id': 47737, 'country': 'IR', 'sunrise': 1781399878, 'sunset': 1781452272}, 'timezone': 12600, 'id': 112931, 'name': 'Tehran', 'cod': 200}

# %%
import random
bazi=["sang","kaqaz","qeychi"]
sharte_bazi=True
while (sharte_bazi):
    you=input("Entekhab kon(sang,kaqaz,qeychi):")
computer=""
rand=random.randint(0,2)
computer=bazi[rand]
you_point=0
computer_point=0
  if you=="sang"and computer=="kaqaz":
                    computer_point=computer_point+1
  if you=="sang" and computer=="qeychi":
                    you_point=you_point+1

  if you=="kaqaz" and computer=="sang":
                    computer_point=computer_point+1

  if you=="kaqaz" and computer=="qeychi":
                    computer_point=computer_point+1
  if you=="qeychi" and computer=="sang":
                    computer_point=computer_point+1
   if you=="qeychi" and computer=="kaqaz":
                you_point=you_point+1
                print("You:",you,"Computer:",computer)    

print("you:",you_point,"-",you)
print("computer:",computer_point,"-",computer)

    if you_point>=3 or computer_point>=3:
        sharte_bazi=False
    if you_point>computer_point:
        print("you win!")
        else
        print("you lose:(")
# Out:
#   File <tokenize>:23
#     if you=="qeychi" and computer=="kaqaz":
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
import random

bazi=["sang","kaqaz","qeychi"]
sharte_bazi=True

you_point=0
computer_point=0

while (sharte_bazi):
    you=input("Entekhab kon(sang,kaqaz,qeychi):")

    computer=""
    rand=random.randint(0,2)
    computer=bazi[rand]

    if you=="sang" and computer=="kaqaz":
        computer_point=computer_point+1

    if you=="sang" and computer=="qeychi":
        you_point=you_point+1

    if you=="kaqaz" and computer=="sang":
        you_point=you_point+1

    if you=="kaqaz" and computer=="qeychi":
        computer_point=computer_point+1

    if you=="qeychi" and computer=="sang":
        computer_point=computer_point+1

    if you=="qeychi" and computer=="kaqaz":
        you_point=you_point+1

    print("You:",you,"Computer:",computer)

    print("you:",you_point,"-",you)
    print("computer:",computer_point,"-",computer)

    if you_point>=3 or computer_point>=3:
        sharte_bazi=False

if you_point>computer_point:
    print("you win!")
else:
    print("you lose:(")
# Out:
# You: سشدل Computer: sang
# you: 0 - سشدل
# computer: 0 - sang
# You: نشضشظ Computer: qeychi
# you: 0 - نشضشظ
# computer: 0 - qeychi
# You: ضثعزه Computer: sang
# you: 0 - ضثعزه
# computer: 0 - sang
# You: نشضشظ Computer: qeychi
# you: 0 - نشضشظ
# computer: 0 - qeychi
# You: نشضشظ Computer: sang
# you: 0 - نشضشظ
# computer: 0 - sang
# You: نشضشظ Computer: qeychi
# you: 0 - نشضشظ
# computer: 0 - qeychi
# You: سشدل Computer: sang
# you: 0 - سشدل
# computer: 0 - sang
# You: سشدل Computer: qeychi
# you: 0 - سشدل
# computer: 0 - qeychi
# You: ضثغزاه Computer: sang
# you: 0 - ضثغزاه
# computer: 0 - sang
# You: سشدل Computer: qeychi
# you: 0 - سشدل
# computer: 0 - qeychi
# You: سشدل Computer: kaqaz
# you: 0 - سشدل
# computer: 0 - kaqaz
# You: sang Computer: qeychi
# you: 1 - sang
# computer: 0 - qeychi
# You: kaqaz Computer: kaqaz
# you: 1 - kaqaz
# computer: 0 - kaqaz
# You: sang Computer: kaqaz
# you: 1 - sang
# computer: 1 - kaqaz
# You: sang Computer: qeychi
# you: 2 - sang
# computer: 1 - qeychi
# You: qeychi Computer: kaqaz
# you: 3 - qeychi
# computer: 1 - kaqaz
# you win!
