# %%
def square(number):
    result=number**2
    return result
user_number=input("یک عدد وارد کنید")
number=int(user_number)
square=square(number)
print (f"مربع  {number}  برابر است با  {square}")
# Out:
# مربع  4  برابر است با  16
